# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\Abhijeet\Desktop\swiggy.csv")

# %%
df.head(10)
# Out:
#     ID         Area       City                                    Restaurant  \
# 0  211  Koramangala  Bangalore                                   Tandoor Hut
# 1  221  Koramangala  Bangalore                                 Tunday Kababi
# 2  246    Jogupalya  Bangalore                                       Kim Lee
# 3  248  Indiranagar  Bangalore                             New Punjabi Hotel
# 4  249  Indiranagar  Bangalore                                           Nh8
# 5  254  Indiranagar  Bangalore                                         Treat
# 6  258  Indiranagar  Bangalore                     Chinita Real Mexican Food
# 7  263  Koramangala  Bangalore  Cupcake Noggins - Cakespastries And Desserts
# 8  267       Domlur  Bangalore                                      Tea Brew
# 9  308  Koramangala  Bangalore                                    Bangaliana
#
#     Price  Avg ratings  Total ratings  \
# 0   300.0          4.4            100
# 1   300.0          4.1            100
# ...

# %%
df.dropna()
# Out:
#           ID                    Area       City                Restaurant  \
# 0        211             Koramangala  Bangalore               Tandoor Hut
# 1        221             Koramangala  Bangalore             Tunday Kababi
# 2        246               Jogupalya  Bangalore                   Kim Lee
# 3        248             Indiranagar  Bangalore         New Punjabi Hotel
# 4        249             Indiranagar  Bangalore                       Nh8
# ...      ...                     ...        ...                       ...
# 8675  464626  Panjarapole Cross Road  Ahmedabad                Malt Pizza
# 8676  465835                  Rohini      Delhi  Jay Mata Ji Home Kitchen
# 8677  465872                  Rohini      Delhi      Chinese Kitchen King
# 8678  465990                  Rohini      Delhi    Shree Ram Paratha Wala
# 8679  466488             Navrangpura  Ahmedabad              Sassy Street
#
#       Price  Avg ratings  Total ratings  \
# ...

# %%
df.shape
# Out:
# (8680, 10)

# %%
df.isna()
# Out:
#          ID   Area   City  Restaurant  Price  Avg ratings  Total ratings  \
# 0     False  False  False       False  False        False          False
# 1     False  False  False       False  False        False          False
# 2     False  False  False       False  False        False          False
# 3     False  False  False       False  False        False          False
# 4     False  False  False       False  False        False          False
# ...     ...    ...    ...         ...    ...          ...            ...
# 8675  False  False  False       False  False        False          False
# 8676  False  False  False       False  False        False          False
# 8677  False  False  False       False  False        False          False
# 8678  False  False  False       False  False        False          False
# 8679  False  False  False       False  False        False          False
#
#       Food type  Address  Delivery time
# 0         False    False          False
# ...

# %%
null=df.isnull()
print(len(null))
# Out:
# 8680

# %%
na=df.isna()
print(len(na))
# Out:
# 8680

# %%
df
# Out:
#           ID                    Area       City                Restaurant  \
# 0        211             Koramangala  Bangalore               Tandoor Hut
# 1        221             Koramangala  Bangalore             Tunday Kababi
# 2        246               Jogupalya  Bangalore                   Kim Lee
# 3        248             Indiranagar  Bangalore         New Punjabi Hotel
# 4        249             Indiranagar  Bangalore                       Nh8
# ...      ...                     ...        ...                       ...
# 8675  464626  Panjarapole Cross Road  Ahmedabad                Malt Pizza
# 8676  465835                  Rohini      Delhi  Jay Mata Ji Home Kitchen
# 8677  465872                  Rohini      Delhi      Chinese Kitchen King
# 8678  465990                  Rohini      Delhi    Shree Ram Paratha Wala
# 8679  466488             Navrangpura  Ahmedabad              Sassy Street
#
#       Price  Avg ratings  Total ratings  \
# ...

# %%
Average_order_val=df['Price'].mean()
print(Average_order_val)
# Out:
# 348.4444700460829

# %%
p=df['Food type'].values
print(p)
# Out:
# ['Biryani,Chinese,North Indian,South Indian' 'Mughlai,Lucknowi' 'Chinese'
#  ... 'Chinese,Snacks,Tandoor' 'North Indian,Indian,Snacks'
#  'Chaat,Snacks,Chinese']

# %%
df['Veg/Non Veg']=df['Food type'].apply(lambda x: 'Veg' if x in ['North Indian,Indian,Snacks'] else 'Non-Veg')
df
# Out:
#           ID                    Area       City                Restaurant  \
# 0        211             Koramangala  Bangalore               Tandoor Hut
# 1        221             Koramangala  Bangalore             Tunday Kababi
# 2        246               Jogupalya  Bangalore                   Kim Lee
# 3        248             Indiranagar  Bangalore         New Punjabi Hotel
# 4        249             Indiranagar  Bangalore                       Nh8
# ...      ...                     ...        ...                       ...
# 8675  464626  Panjarapole Cross Road  Ahmedabad                Malt Pizza
# 8676  465835                  Rohini      Delhi  Jay Mata Ji Home Kitchen
# 8677  465872                  Rohini      Delhi      Chinese Kitchen King
# 8678  465990                  Rohini      Delhi    Shree Ram Paratha Wala
# 8679  466488             Navrangpura  Ahmedabad              Sassy Street
#
#       Price  Avg ratings  Total ratings  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
category_counts = df['Veg/Non Veg'].value_counts()
category_counts.plot(kind='bar', rot=0)
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Distribution of Food Categories')
plt.show()

# %%
df['Veg/Non Veg'].value_counts()
# Out:
# Veg/Non Veg
# Non-Veg    8679
# Veg           1
# Name: count, dtype: int64

# %%
df['Restaurant'].value_counts()
# Out:
# Restaurant
# La Pino'Z Pizza           13
# Nic Natural Ice Creams    10
# Baskin Robbins            10
# Subway                    10
# Kfc                        9
#                           ..
# Home Factory               1
# Meals And Bowls            1
# Waffle Dreams              1
# Pratik Restaurant          1
# Sassy Street               1
# Name: count, Length: 7865, dtype: int64

# %%
df.head(5)
# Out:
#     ID         Area       City         Restaurant  Price  Avg ratings  \
# 0  211  Koramangala  Bangalore        Tandoor Hut  300.0          4.4
# 1  221  Koramangala  Bangalore      Tunday Kababi  300.0          4.1
# 2  246    Jogupalya  Bangalore            Kim Lee  650.0          4.4
# 3  248  Indiranagar  Bangalore  New Punjabi Hotel  250.0          3.9
# 4  249  Indiranagar  Bangalore                Nh8  350.0          4.0
#
#    Total ratings                                          Food type  \
# 0            100          Biryani,Chinese,North Indian,South Indian
# 1            100                                   Mughlai,Lucknowi
# 2            100                                            Chinese
# 3            500               North Indian,Punjabi,Tandoor,Chinese
# 4             50  Rajasthani,Gujarati,North Indian,Snacks,Desser...
#
#         Address  Delivery time Veg/Non Veg
# 0     5Th Block             59     Non-Veg
# 1     5Th Block             56     Non-Veg
# ...

# %%
category_counts = df['City'].value_counts()
category_counts.plot(kind='bar', rot=90)
plt.xlabel('City')
plt.ylabel('Count')
plt.title('Orders fron Various City')
plt.show()

# %%
Avg_delivery_time=df['Delivery time'].mean()
print(Avg_delivery_time)
# Out:
# 53.96705069124424

# %%
Avg_delivery_time_per_city=df.groupby('City')['Delivery time'].mean()
#category_counts = df['City'].value_counts()
Avg_delivery_time_per_city.plot(kind='bar', rot=90)
plt.xlabel('City')
plt.ylabel('time')
plt.title("Avg Delivery time(minutes) ")
plt.show()

# %%
Delivery_by_area=df[df['City'] == 'Bangalore'].groupby('Area')['City'].count().sort_values(ascending=False)
top_ten_area=Delivery_by_area.head(10)
top_ten_area.plot(figsize=[10,5],kind='bar',rot=90)
plt.xlabel('Area')
plt.ylabel('Count')
plt.title('Top Ten Areas with Most Orders in Bangalore')
plt.show()

# %%
Avg_order_amount=df.groupby('City')['Price'].mean().sort_values(ascending=False)
#top_ten_area=Avg_order_amount.head(10)
Avg_order_amount.plot(figsize=[10,5],kind='bar',rot=90)
plt.xlabel('City')
plt.ylabel('Amount')
plt.title('Average Order Amount per city(Rs)')
plt.show()

# %%
Delivery_by_area=df[df['City'] == 'Pune'].groupby('Area')['City'].count().sort_values(ascending=False)
top_ten_area=Delivery_by_area.head(10)
top_ten_area.plot(figsize=[10,5],kind='bar',rot=90)
plt.xlabel('Area')
plt.ylabel('Count')
plt.title('Top Ten Areas with Most Orders in Pune')
plt.show()

# %%
delivery_by_a=df[df['City']=='Kolkata'].groupby('Area')['City'].count().sort_values(ascending=False)
top_ten_area=delivery_by_a.head(10)
top_ten_area.plot(figsize=[10,5],kind='bar',rot=90)
plt.xlabel('Area')
plt.ylabel('Count')
plt.title('Top Ten Areas with Most Orders in Kolkata')
plt.show()

# %%
delivery_by_area=df[df['City']=='Chennai'].groupby('Area')['City'].count().sort_values(ascending=False)
delivery_in_top_10=delivery_by_area.head(10)
delivery_in_top_10.plot(figsize=[10,5],kind='bar',rot=90)
plt.xlabel('Area')
plt.ylabel('Count')
plt.title('Top Ten areas With Most orders in Chennai')    
plt.show()

# %%
delivery_by_area=df[df['City']=='Delhi'].groupby('Area')['City'].count().sort_values(ascending=False)
delivery_in_top_10=delivery_by_area.head(10)
delivery_in_top_10.plot(figsize=[10,5],kind='bar',rot=90)
plt.xlabel('Area')
plt.ylabel('Count')
plt.title('Top Ten areas With Most orders in Delhi')    
plt.show()

# %%
delivery_by_area=df[df['City']=='Ahmedabad'].groupby('Area')['City'].count().sort_values(ascending=False)
delivery_in_top_10=delivery_by_area.head(10)
delivery_in_top_10.plot(figsize=[10,5],kind='bar',rot=90)
plt.xlabel('Area')
plt.ylabel('Count')
plt.title('Top Ten areas With Most orders in Ahmedabad')    
plt.show()

# %%
delivery_by_area=df[df['City']=='Surat'].groupby('Area')['City'].count().sort_values(ascending=False)
delivery_in_top_10=delivery_by_area.head(10)
delivery_in_top_10.plot(figsize=[10,5],kind='bar',rot=90)
plt.xlabel('Area')
plt.ylabel('Count')
plt.title('Top Ten areas With Most orders in Surat')    
plt.show()

# %%
delivery_by_area=df[df['City']=='Hyderabad'].groupby('Area')['City'].count().sort_values(ascending=False)
delivery_in_top_10=delivery_by_area.head(10)
delivery_in_top_10.plot(figsize=[10,5],kind='bar',rot=90)
plt.xlabel('Area')
plt.ylabel('Count')
plt.title('Top Ten areas With Most orders in Hyderabad')    
plt.show()

# %%
delivery_by_area=df[df['City']=='Mumbai'].groupby('Area')['City'].count().sort_values(ascending=False)
delivery_in_top_10=delivery_by_area.head(10)
delivery_in_top_10.plot(figsize=[10,5],kind='bar',rot=90)
plt.xlabel('Area')
plt.ylabel('Count')
plt.title('Top Ten areas With Most orders in Mumbai')    
plt.show()

# %%
dm=df['Delivery time'].mean()
dm
# Out:
# 53.96705069124424

# %%
df.head()
# Out:
#     ID         Area       City         Restaurant  Price  Avg ratings  \
# 0  211  Koramangala  Bangalore        Tandoor Hut  300.0          4.4
# 1  221  Koramangala  Bangalore      Tunday Kababi  300.0          4.1
# 2  246    Jogupalya  Bangalore            Kim Lee  650.0          4.4
# 3  248  Indiranagar  Bangalore  New Punjabi Hotel  250.0          3.9
# 4  249  Indiranagar  Bangalore                Nh8  350.0          4.0
#
#    Total ratings                                          Food type  \
# 0            100          Biryani,Chinese,North Indian,South Indian
# 1            100                                   Mughlai,Lucknowi
# 2            100                                            Chinese
# 3            500               North Indian,Punjabi,Tandoor,Chinese
# 4             50  Rajasthani,Gujarati,North Indian,Snacks,Desser...
#
#         Address  Delivery time Veg/Non Veg
# 0     5Th Block             59     Non-Veg
# 1     5Th Block             56     Non-Veg
# ...

# %%
#Top Rated restaurant in city bangalore above rating 4.5
top_rest_bang=df[(df['City']=='Bangalore')&(df['Avg ratings'] > 4.5)].groupby('Restaurant')['City'].first()
print(top_rest_bang)
# Out:
# Restaurant
# 4Th Tea Block                                         Bangalore
# Anand Sweets And Savouries                            Bangalore
# Art Of Delight                                        Bangalore
# Artinci - Indulge Guilt Free!                         Bangalore
# Azuki Japan Travel  Bistro And Sake                   Bangalore
# Blue Tokai Coffee Roasters                            Bangalore
# Bombay Kulfis                                         Bangalore
# Chaayos Meri Wali Chai                                Bangalore
# Cheese Meets Bread                                    Bangalore
# Chianti                                               Bangalore
# Corner House Ice Cream                                Bangalore
# Creams & Bites                                        Bangalore
# Earthen Delights                                      Bangalore
# Frosty Crumble                                        Bangalore
# ...

# %%
#Top Rated restaurant in city above rating 4.5
top_rest_pune=df[(df['City']=='Pune')&(df['Avg ratings'] > 4.5)].groupby('Restaurant')['City'].first()
print(top_rest_pune)
# Out:
# Restaurant
# Artinci - Indulge Guilt Free!         Pune
# Arun Ice Creams                       Pune
# Ashays Fusion Momo                    Pune
# Barometer                             Pune
# Buddha Paradise                       Pune
# Cafe Chokolade                        Pune
# Cafe Old Skool                        Pune
# Chafa Cafe And Studio                 Pune
# Chitale Ice Cream                     Pune
# Churro Mania                          Pune
# Culture Biryani And Grill             Pune
# Frozen Bottle                         Pune
# Ganesh Bhel                           Pune
# Ganpat Sweets                         Pune
# Gulp                                  Pune
# Healthy Affairs                       Pune
# Huber & Holly                         Pune
# Khichdi Express                       Pune
# Kirti                                 Pune
# Lassi Wassi                           Pune
# Lean Life Bistro                      Pune
# ...

# %%
#Top Rated restaurant in city above rating 4.5
top_rest_pune=df[(df['City']=='Delhi')&(df['Avg ratings'] > 4.5)].groupby('Restaurant')['City'].first()
print(top_rest_pune)
# Out:
# Restaurant
# Biryani By Kilo                                  Delhi
# China Town Kathi Rolls                           Delhi
# Fat Tiger                                        Delhi
# Havmor Havfunn Ice Cream                         Delhi
# Kakas Food Point                                 Delhi
# Keventers Ice Creamery                           Delhi
# Kwality Walls Frozen Dessert & Ice Cream Shop    Delhi
# Lakhan Pan                                       Delhi
# Mosaic By Crowne Plaza Rohini                    Delhi
# Pizza Paradise By Vhc                            Delhi
# Shake'N Food                                     Delhi
# The Dineroom                                     Delhi
# The Sugar Free Keto Kafe - By Artinci            Delhi
# Wok On Fire                                      Delhi
# Name: City, dtype: object

# %%
#Avg order value per city
avg_order_val=df.groupby('City')['Price'].mean()
avg_order_val.plot(figsize=[10,5],kind='bar',rot=0)
plt.xlabel('City')
plt.ylabel('Avg Price')
plt.title('Avg Order value per Order')
plt.show()

# %%
fast_deli=df[(df['City']== 'Pune') & (df['Delivery time']  <30)].groupby('Restaurant').size()
fast_deli
# Out:
# Restaurant
# Frozen Bottle                      1
# Ganesh Bhel-Swargate               1
# Havmor Ice Creamjm Road            1
# Mh 12 Pav Bhaji                    1
# Natural Ice Cream                  1
# Poona Cafe                         1
# Rajendra Paav Bhaji                1
# Rajmandir Ice Cream                1
# Ramsar Bakery                      1
# Sahare Dining Hall                 1
# Sujata Mastani                     1
# Supriya Restaurant                 1
# Sweet Truth - Cake And Desserts    1
# Wadeshwar (Bajirao Road)           1
# dtype: int64

# %%
#count of restaurant by address where city is banglore
restaurant_cnt=df[df['City']=='Bangalore'].groupby('Address')['Restaurant'].nunique().sort_values(ascending=False).reset_index()
restaurant_cnt
# Rename the count column
#result = result.rename(columns={'Restaurant': 'Distinct Restaurant Count'})
# Out:
#                     Address  Restaurant
# 0         Central Bangalore         116
# 1               Indiranagar         103
# 2               Koramangala          94
# 3              Basavanagudi          52
# 4              Malleshwaram          38
# ..                      ...         ...
# 258              Gandinagar           1
# 259   Garuda Mall Wow! Momo           1
# 260            Geddalahalli           1
# 261  Ghandi Bazar Main Road           1
# 262           Yeshwanthpura           1
#
# [263 rows x 2 columns]

# %%
#Insight's
#most Of the orders came #from Central part of the city.
#Every city has 2 or 3 hot spot that orders more 
#most orders came from bachelor or  young working prophational's
#Average order value varies between Rs.250 to Rs.400
#Average Delivery time in cities is 53Min.
